# %%
import pandas as pd
import numpy as np

pd.options.display.max_rows = None
pd.options.display.max_columns = None

n_rows=2e2

Liczby=pd.DataFrame(np.random.normal(size=(int(n_rows),3)),columns=["A","B","C"])
Liczby
# Out:
#             A         B         C
# 0    0.688730 -1.492526  0.006837
# 1   -0.551450  0.862726  1.443705
# 2    1.015031 -0.305005 -0.058416
# 3   -1.271849  0.334870  0.014417
# 4    1.459178 -0.028153 -0.156007
# 5   -0.538778 -0.482076 -1.202228
# 6    0.684588 -0.947252  1.720967
# 7    0.661548  0.260490 -1.197803
# 8    0.948127 -1.452478  1.385002
# 9   -0.693168  0.918808  0.354139
# 10   0.914632  1.959493 -0.990170
# 11  -0.943366 -1.477774  2.008950
# 12   0.238474  0.182520  0.976247
# 13  -1.067037 -0.844503 -0.718388
# 14  -2.363053 -0.567642 -0.149300
# 15   0.596083 -2.487245  0.077547
# 16  -1.021156  1.103942  0.491453
# 17   0.283452  1.899637  1.854244
# 18  -1.415907  0.209618  0.970184
# 19  -1.282377  1.117639 -0.079458
# 20  -0.799216 -0.781866  0.441567
# 21  -0.763691 -0.701623  0.281720
# 22  -0.907844  0.715325  0.694166
# 23  -0.383321 -0.840010 -0.037100
# 24   1.373642  0.210091 -1.750845
# 25  -2.095239  0.090933 -1.657182
# ...
