# %%
import pandas as pd
import numpy as np
print("Downloaded")

Liczby=pd.DataFrame(np.random.normal(size=(100,3)),columns=["A","B","C"])
Liczby
# Out:
# Downloaded
#            A         B         C
# 0   0.061222  0.458504  1.078255
# 1   0.324753 -2.165030  1.922956
# 2  -0.249173 -0.142436  0.903504
# 3   0.526955  1.654556  1.792223
# 4  -1.557108 -0.681557  1.004484
# ..       ...       ...       ...
# 95  1.809323  1.022739 -0.866663
# 96 -0.550175 -0.969392 -0.385399
# 97  1.165704  0.007350  0.387956
# 98  1.916114  0.102652  0.870488
# 99  0.311150 -0.349880 -2.298514
#
# [100 rows x 3 columns]
