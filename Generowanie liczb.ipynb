# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(12345)

pd.options.display.max_rows = None
pd.options.display.max_columns = None
pd.set_option("display.precision", 8)

n_rows=5e2

Liczby=pd.DataFrame(np.random.normal(size=(int(n_rows),3)),columns=["A","B","C"])
display(Liczby)
Liczby.describe()
# Out:
#               A           B           C
# 0   -0.20470766  0.47894334 -0.51943872
# 1   -0.55573030  1.96578057  1.39340583
# 2    0.09290788  0.28174615  0.76902257
# 3    1.24643474  1.00718936 -1.29622111
# 4    0.27499163  0.22891288  1.35291684
# 5    0.88642934 -2.00163731 -0.37184254
# 6    1.66902531 -0.43856974 -0.53974145
# 7    0.47698501  3.24894392 -1.02122752
# 8   -0.57708730  0.12412128  0.30261356
# 9    0.52377207  0.00094028  1.34380979
# 10  -0.71354399 -0.83115354 -2.37023165
# 11  -1.86076079 -0.86075740  0.56014529
# 12  -1.26593449  0.11982712 -1.06351245
# 13   0.33288272 -2.35941881 -0.19954296
# 14  -1.54199553 -0.97073591 -1.30703025
# 15   0.28634975  0.37798411 -0.75388653
# 16   0.33128565  1.34974221  0.06987669
# 17   0.24667411 -0.01186160  1.00481159
# 18   1.32719461 -0.91926156 -1.54910644
# 19   0.02218460  0.75836315 -0.66052433
# 20   0.86258008 -0.01003190  0.05000936
# 21   0.67021559  0.85296503 -0.95586885
# ...

# %%
kolory_hex = ['#000080']

plt.figure()

plt.scatter(Liczby['A'], Liczby['B'], c=kolory_hex)
plt.xlabel('A')  
plt.ylabel('B')

plt.xlim(-6, 6)
plt.ylim(-4, 4)

plt.title('Wykres punktowy kolumn A i B') 
plt.colorbar(label='B')  
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D 

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

kolory_hex = ['#000080']

mappable = ax.scatter(Liczby['A'], Liczby['B'], Liczby['C'], c=kolory_hex)

ax.set_xlabel('A')
ax.set_ylabel('B')
ax.set_zlabel('C')

ax.set_xlim(-4, 4)  
ax.set_ylim(-4, 4)  
ax.set_zlim(-4, 4)  

ax.set_title('Wykres punktowy 3D kolumn A, B i C')

plt.show()

# %%
Liczby['D']=Liczby['A']+Liczby['B']+Liczby['C']
Liczby.describe()
# Out:
#                   A             B             C             D
# count  500.00000000  500.00000000  500.00000000  500.00000000
# mean    -0.00778633    0.02271803   -0.05262634   -0.03769464
# std      0.97876430    1.00066690    0.99204444    1.70547860
# min     -2.98974099   -2.61230270   -3.39931182   -5.97522518
# 25%     -0.65864939   -0.69069011   -0.69321643   -1.09068990
# 50%     -0.01707424   -0.01098846   -0.10502093   -0.13350212
# 75%      0.56753563    0.64214202    0.61575114    1.10343138
# max      2.73552719    3.92752804    3.26038307    5.26188350
